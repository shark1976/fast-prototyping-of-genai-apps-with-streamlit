# %% [markdown]
# `Module 2`
# # Uploading a Batch of Files

# %% [markdown]
# ## Download DOCX files
#
# - Download a set of 100 DOCX files of customer reviews as a zipped file called [customer_reviews_docx.zip](https://github.com/https-deeplearning-ai/fast-prototyping-of-genai-apps-with-streamlit/blob/main/data/customer_reviews_docx.zip)
# - Unzip the `customer_reviews_docx.zip` file
# - Upload the 100 DOCX files to a stage located at `AVALANCHE_DB` database, `AVALANCHE_SCHEMA` and `AVALANCHE_STAGE` (or click on this direct link to the [`AVALANCHE_STAGE`](https://app.snowflake.com/_deeplink/#/data/databases/AVALANCHE_DB/schemas/AVALANCHE_SCHEMA/stage/AVALANCHE_STAGE))

# %% [markdown]
# ## List contents of the stage
#
# Here, you should see the 100 DOCX files amongst the returned output.

# %%
LIST @Avalanche_Stage

# %% [markdown]
# ## Count files in stage
#
# Here, you should see at least 100 files.

# %%
SELECT COUNT(*) FROM DIRECTORY(@AVALANCHE_STAGE);
